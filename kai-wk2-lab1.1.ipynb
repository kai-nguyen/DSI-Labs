# %%
import pandas as pd
starwars = pd.read_csv('https://raw.githubusercontent.com/fivethirtyeight/data/master/star-wars-survey/StarWars.csv')

head = starwars.head()
print head
# Out:
#    RespondentID Have you seen any of the 6 films in the Star Wars franchise?  \
# 0           NaN                                           Response
# 1  3.292880e+09                                                Yes
# 2  3.292880e+09                                                 No
# 3  3.292765e+09                                                Yes
# 4  3.292763e+09                                                Yes
#
#   Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 0                                           Response
# 1                                                Yes
# 2                                                NaN
# 3                                                 No
# 4                                                Yes
#
#   Which of the following Star Wars films have you seen? Please select all that apply.  \
# 0           Star Wars: Episode I  The Phantom Menace
# 1           Star Wars: Episode I  The Phantom Menace
# ...

# %%
tail = starwars.tail()
print tail
# Out:
#       RespondentID  \
# 1182  3.288389e+09
# 1183  3.288379e+09
# 1184  3.288375e+09
# 1185  3.288373e+09
# 1186  3.288373e+09
#
#      Have you seen any of the 6 films in the Star Wars franchise?  \
# 1182                                                Yes
# 1183                                                Yes
# 1184                                                 No
# 1185                                                Yes
# 1186                                                Yes
#
#      Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 1182                                                Yes
# 1183                                                Yes
# 1184                                                NaN
# 1185                                                Yes
# 1186                                                 No
#
#      Which of the following Star Wars films have you seen? Please select all that apply.  \
# ...

# %%
describe = starwars.describe()
print describe
# Out:
#        RespondentID
# count  1.186000e+03
# mean   3.290128e+09
# std    1.055639e+06
# min    3.288373e+09
# 25%    3.289451e+09
# 50%    3.290147e+09
# 75%    3.290814e+09
# max    3.292880e+09

# %%
respondent_column = starwars['RespondentID']
print respondent_column
# Out:
# 0                NaN
# 1       3.292880e+09
# 2       3.292880e+09
# 3       3.292765e+09
# 4       3.292763e+09
# 5       3.292731e+09
# 6       3.292719e+09
# 7       3.292685e+09
# 8       3.292664e+09
# 9       3.292654e+09
# 10      3.292640e+09
# 11      3.292638e+09
# 12      3.292635e+09
# 13      3.292609e+09
# 14      3.292597e+09
# 15      3.292587e+09
# 16      3.292583e+09
# 17      3.292581e+09
# 18      3.292573e+09
# 19      3.292565e+09
# 20      3.292562e+09
# 21      3.292522e+09
# 22      3.292521e+09
# 23      3.292512e+09
# 24      3.292483e+09
# 25      3.292465e+09
# 26      3.292448e+09
# 27      3.292420e+09
# 28      3.292384e+09
# 29      3.292380e+09
#             ...
# 1157    3.288426e+09
# 1158    3.288423e+09
# 1159    3.288423e+09
# 1160    3.288422e+09
# 1161    3.288421e+09
# 1162    3.288418e+09
# 1163    3.288418e+09
# 1164    3.288417e+09
# 1165    3.288415e+09
# 1166    3.288414e+09
# 1167    3.288413e+09
# 1168    3.288410e+09
# ...

# %%
starwars_slice = starwars[1:6]
print starwars_slice
# Out:
#    RespondentID Have you seen any of the 6 films in the Star Wars franchise?  \
# 1  3.292880e+09                                                Yes
# 2  3.292880e+09                                                 No
# 3  3.292765e+09                                                Yes
# 4  3.292763e+09                                                Yes
# 5  3.292731e+09                                                Yes
#
#   Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 1                                                Yes
# 2                                                NaN
# 3                                                 No
# 4                                                Yes
# 5                                                Yes
#
#   Which of the following Star Wars films have you seen? Please select all that apply.  \
# 1           Star Wars: Episode I  The Phantom Menace
# 2                                                NaN
# ...

# %%
starwars_iloc = starwars.iloc[3,2]
print starwars_iloc
# Out:
# No

# %%
starwars_slice_column = starwars.iloc[:,2:5]
print starwars_slice_column
# Out:
#      Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 0                                              Response
# 1                                                   Yes
# 2                                                   NaN
# 3                                                    No
# 4                                                   Yes
# 5                                                   Yes
# 6                                                   Yes
# 7                                                   Yes
# 8                                                   Yes
# 9                                                   Yes
# 10                                                   No
# 11                                                  NaN
# 12                                                  NaN
# 13                                                   No
# 14                                                  Yes
# ...

# %%
starwars.dtypes
# Out:
# RespondentID                                                                                                                                     float64
# Have you seen any of the 6 films in the Star Wars franchise?                                                                                      object
# Do you consider yourself to be a fan of the Star Wars film franchise?                                                                             object
# Which of the following Star Wars films have you seen? Please select all that apply.                                                               object
# Unnamed: 4                                                                                                                                        object
# Unnamed: 5                                                                                                                                        object
# ...

# %%
starwars.iloc[1:,0].astype(int)
# Out:
# 1       3292879998
# 2       3292879538
# 3       3292765271
# 4       3292763116
# 5       3292731220
# 6       3292719380
# 7       3292684787
# 8       3292663732
# 9       3292654043
# 10      3292640424
# 11      3292637870
# 12      3292635062
# 13      3292609214
# 14      3292596911
# 15      3292587240
# 16      3292583038
# 17      3292580516
# 18      3292572872
# 19      3292565282
# 20      3292562297
# 21      3292522349
# 22      3292521066
# 23      3292511801
# 24      3292483200
# 25      3292465491
# 26      3292447974
# 27      3292420123
# 28      3292384040
# 29      3292380493
# 30      3292376985
#            ...
# 1157    3288425859
# 1158    3288423088
# 1159    3288423045
# 1160    3288421819
# 1161    3288420798
# 1162    3288417782
# 1163    3288417641
# 1164    3288416959
# 1165    3288415166
# 1166    3288414025
# 1167    3288413441
# 1168    3288410348
# 1169    3288410073
# 1170    3288408698
# 1171    3288402717
# 1172    3288402643
# ...

# %%
dummies = pd.get_dummies(starwars['Age'][1:6])
print dummies
# Out:
#    18-29
# 1    1.0
# 2    1.0
# 3    1.0
# 4    1.0
# 5    1.0
